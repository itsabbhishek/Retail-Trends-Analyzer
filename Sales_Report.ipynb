# %% [markdown]
# # Sales Performance Analysis and Strategic Insights Project

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_excel('Sales Data.xlsx')

# %%
df.shape
# Out:
# (62665, 22)

# %%
df.head()
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity     Sales  \
# 0  6765.0   48192.0 2009-12-16       Critical            15.0  2277.670
# 1   193.0    1285.0 2012-05-31       Critical            27.0  3874.120
# 2  7321.0   52194.0 2010-12-11       Critical            12.0  1551.340
# 3  2302.0   16582.0 2011-10-01       Critical            26.0  6766.856
# 4  2056.0   14693.0 2011-01-09       Critical            38.0   847.820
#
#    Discount       Ship Mode       Profit  Unit Price  ...          Province  \
# 0      0.00  Delivery Truck  -173.960000      140.98  ...  British Columbia
# 1      0.00  Delivery Truck  -305.980000      130.98  ...       Nova Scotia
# 2      0.03  Delivery Truck  -483.120000      120.98  ...            Quebec
# 3      0.02  Delivery Truck  -774.890688      320.64  ...            Quebec
# 4      0.05  Delivery Truck -1348.500000       20.98  ...           Ontario
#
#      Region Customer Segment Product Category    Product Sub-Category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62665 entries, 0 to 62664
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                53768 non-null  float64
#  1   Order ID              53768 non-null  float64
#  2   Order Date            53768 non-null  datetime64[ns]
#  3   Order Priority        53768 non-null  object
#  4   Order Quantity        53768 non-null  float64
#  5   Sales                 53768 non-null  float64
#  6   Discount              53768 non-null  float64
#  7   Ship Mode             53768 non-null  object
#  8   Profit                53768 non-null  float64
#  9   Unit Price            53768 non-null  float64
#  10  Shipping Cost         53768 non-null  float64
#  11  Customer Name         53768 non-null  object
#  12  Province              53768 non-null  object
#  13  Region                53768 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Row ID                  8897
# Order ID                8897
# Order Date              8897
# Order Priority          8897
# Order Quantity          8897
# Sales                   8897
# Discount                8897
# Ship Mode               8897
# Profit                  8897
# Unit Price              8897
# Shipping Cost           8897
# Customer Name           8897
# Province                8897
# Region                  8897
# Customer Segment        8897
# Product Category        8897
# Product Sub-Category    8897
# Product Name            8897
# Product Container       8897
# Product Base Margin     9233
# Ship Date               8897
# Year                    8897
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Row ID                  0
# Order ID                0
# Order Date              0
# Order Priority          0
# Order Quantity          0
# Sales                   0
# Discount                0
# Ship Mode               0
# Profit                  0
# Unit Price              0
# Shipping Cost           0
# Customer Name           0
# Province                0
# Region                  0
# Customer Segment        0
# Product Category        0
# Product Sub-Category    0
# Product Name            0
# Product Container       0
# Product Base Margin     0
# Ship Date               0
# Year                    0
# dtype: int64

# %%
df.shape # sHape After Removing Null values
# Out:
# (53432, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 53432 entries, 0 to 62664
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                53432 non-null  float64
#  1   Order ID              53432 non-null  float64
#  2   Order Date            53432 non-null  datetime64[ns]
#  3   Order Priority        53432 non-null  object
#  4   Order Quantity        53432 non-null  float64
#  5   Sales                 53432 non-null  float64
#  6   Discount              53432 non-null  float64
#  7   Ship Mode             53432 non-null  object
#  8   Profit                53432 non-null  float64
#  9   Unit Price            53432 non-null  float64
#  10  Shipping Cost         53432 non-null  float64
#  11  Customer Name         53432 non-null  object
#  12  Province              53432 non-null  object
#  13  Region                53432 non-null  object
# ...

# %%
df['Row ID']=df['Row ID'].astype(int)

# %%
df['Order ID']=df['Order ID'].astype(int)

# %%
df['Sales']=df['Sales'].astype(int)

# %%
df['Year']=df['Year'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 53432 entries, 0 to 62664
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                53432 non-null  int32
#  1   Order ID              53432 non-null  int32
#  2   Order Date            53432 non-null  datetime64[ns]
#  3   Order Priority        53432 non-null  object
#  4   Order Quantity        53432 non-null  float64
#  5   Sales                 53432 non-null  int32
#  6   Discount              53432 non-null  float64
#  7   Ship Mode             53432 non-null  object
#  8   Profit                53432 non-null  float64
#  9   Unit Price            53432 non-null  float64
#  10  Shipping Cost         53432 non-null  float64
#  11  Customer Name         53432 non-null  object
#  12  Province              53432 non-null  object
#  13  Region                53432 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Order Priority', 'Order Quantity',
#        'Sales', 'Discount', 'Ship Mode', 'Profit', 'Unit Price',
#        'Shipping Cost', 'Customer Name', 'Province', 'Region',
#        'Customer Segment', 'Product Category', 'Product Sub-Category',
#        'Product Name', 'Product Container', 'Product Base Margin', 'Ship Date',
#        'Year'],
#       dtype='object')

# %% [markdown]
# # NUMBERS OF CUSTOMERS

# %%
customer_counts = df['Customer Name'].value_counts()
print("Number of customers:", len(customer_counts))
# Out:
# Number of customers: 791

# %% [markdown]
# # HOW MANY ORDERS

# %%
num_orders = len(df['Order ID'])
print("Total number of orders:", num_orders)
# Out:
# Total number of orders: 53432

# %% [markdown]
# # TOTAL SALES

# %%
total_sales = df['Sales'].sum()
print("Total sales:", total_sales)
# Out:
# Total sales: 95348952

# %% [markdown]
# # PROFIT %

# %%
total_profit = df['Profit'].sum()
total_sales = df['Sales'].sum()

profit_percentage = (total_profit / total_sales) * 100
print("Profit percentage:", profit_percentage)
# Out:
# Profit percentage: 10.73455988641805

# %% [markdown]
# # TOTAL SALES IN EACH REGION

# %%
total_sales_by_region = df.groupby('Region')['Sales'].sum()
print("Total sales in each region:")
print(total_sales_by_region)
# Out:
# Total sales in each region:
# Region
# Atlantic                 13589552
# Northwest Territories     4801768
# Nunavut                    676360
# Ontario                  20217768
# Prarie                   17377264
# Quebec                    9731848
# West                     22934208
# Yukon                     6020184
# Name: Sales, dtype: int32

# %% [markdown]
# # TOTAL SALES IN EACH PROVIENCE

# %%
total_sales_by_province = df.groupby('Province')['Sales'].sum()
print("Total sales in each province:")
print(total_sales_by_province)
# Out:
# Total sales in each province:
# Province
# Alberta                  10525552
# British Columbia         12408656
# Manitoba                  8644672
# New Brunswick             4639736
# Newfoundland               634800
# Northwest Territories     4801768
# Nova Scotia               5483160
# Nunavut                    676360
# Ontario                  20217768
# Prince Edward Island      2831856
# Quebec                    9731848
# Saskachewan               8732592
# Yukon                     6020184
# Name: Sales, dtype: int32

# %% [markdown]
# # PRODUCT CATEGORY

# %%
sales_by_category = df.groupby('Product Category')['Sales'].sum()

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(sales_by_category, labels=sales_by_category.index, autopct='%1.1f%%', startangle=140)
plt.title('Sales Distribution by Product Category')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# # PRODUCT SUB CATEGORY

# %%
sales_by_subcategory = df.groupby('Product Sub-Category')['Sales'].sum()

# Sorting the values for better visualization
sales_by_subcategory = sales_by_subcategory.sort_values(ascending=False)

# Convert sales to millions
sales_by_subcategory_millions = sales_by_subcategory / 1000000  # Convert to millions

# Creating the bar chart
plt.figure(figsize=(12, 6))
sales_by_subcategory_millions.plot(kind='bar', color='skyblue')
plt.title('Product Sub-Category by Sales (Millions)')
plt.xlabel('Product Sub-Category')
plt.ylabel('Sales (Millions)')
plt.xticks(rotation=45, ha='right')

# Displaying the values on top of each bar
for i, sales in enumerate(sales_by_subcategory_millions):
    plt.text(i, sales, f'{sales:.1f}M', ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %% [markdown]
# # SHIP MODE

# %%
sales_by_ship_mode = df.groupby('Ship Mode')['Sales'].sum()

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(sales_by_ship_mode, labels=sales_by_ship_mode.index, autopct='%1.1f%%', startangle=140)
plt.title('Sales Distribution by Ship Mode')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# # CUSTOMER SEGMENT

# %%
sales_by_segment = df.groupby('Customer Segment')['Sales'].sum()

# Sorting the values for better visualization
sales_by_segment = sales_by_segment.sort_values(ascending=False)

# Creating the bar chart
plt.figure(figsize=(10, 6))
sales_by_segment.plot(kind='bar', color='skyblue')
plt.title('Total Sales by Customer Segment')
plt.xlabel('Customer Segment')
plt.ylabel('Total Sales')
plt.xticks(rotation=45, ha='right')

# Displaying the values on top of each bar
for i, sales in enumerate(sales_by_segment):
    plt.text(i, sales, f'{sales:.2f}', ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %%
sales_profit_by_year = df.groupby('Year').agg({'Sales': 'sum', 'Profit': 'sum'})

# Calculate profit percentage
sales_profit_by_year['Profit_Percentage'] = (sales_profit_by_year['Profit'] / sales_profit_by_year['Sales']) * 100

# Creating the chart
fig, ax1 = plt.subplots(figsize=(10, 6))

# Plotting Sales
ax1.bar(sales_profit_by_year.index, sales_profit_by_year['Sales'], color='skyblue', label='Sales')
ax1.set_xlabel('Year')
ax1.set_ylabel('Sales')

# Creating the secondary y-axis for Profit Percentage
ax2 = ax1.twinx()
ax2.plot(sales_profit_by_year.index, sales_profit_by_year['Profit_Percentage'], color='orange', marker='o', linewidth=2, label='Profit %')
ax2.set_ylabel('Profit Percentage (%)')

# Adding legend
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines1 + lines2, labels1 + labels2, loc='upper left')

# Adding title
plt.title('Sales and Profit Percentage by Year')

plt.show()

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# ## Data Cleaning and Preprocessing:
#
# The dataset initially contained 62,665 entries and 22 columns. After removing rows with missing values, the dataset was reduced to 53,432 entries.
# Columns like 'Row ID' and 'Order ID' were converted to integer data type for better processing.

# %% [markdown]
# ## Data Summary:
#
# The dataset comprises various columns such as order details, sales information, customer details, and product information.
# The total number of customers is 791, and the total number of orders is 53,432.
# The total sales recorded in the dataset amount to $95,348,952.

# %% [markdown]
# ## Sales Analysis:
#
# Sales were analyzed across different regions and provinces. The total sales in each region and province were calculated and visualized using bar charts and pie charts.
# The 'West' region recorded the highest total sales, followed by 'Prarie' and 'Ontario' regions.
# Among provinces, 'Alberta', 'British Columbia', and 'Ontario' recorded the highest total sales.

# %% [markdown]
# ## Product Analysis:
#
# Sales distribution by product category and sub-category was visualized using pie charts and bar charts, respectively.
# 'Technology' emerged as the top-selling product category, followed by 'Office Supplies' and 'Furniture'.
# Within the 'Technology' category, 'Phones' and 'Copiers' were the top-selling sub-categories.

# %% [markdown]
# ## Customer Segment Analysis:
#
# Total sales by customer segment were analyzed and visualized using a bar chart.
# The 'Corporate' segment contributed the highest total sales, followed by 'Home Office' and 'Consumer' segments.

# %% [markdown]
# ## Yearly Sales and Profit Analysis:
#
# Sales and profit percentages were analyzed across different years and visualized using a bar chart.
# While sales increased over the years, profit percentages fluctuated, indicating variations in profitability.

# %% [markdown]
# **Overall, the analysis provides valuable insights into sales performance, customer behavior, and product preferences, which can be used for strategic decision-making and improving business profitability. Further analysis could involve exploring trends over time, identifying factors affecting profitability, and conducting customer segmentation analysis for targeted marketing strategies.**

# %% [markdown]
# # Exporting The Filtered Data To Excel

# %%
df.to_excel("C:\\Users\\cw\\Desktop\\New_Sales_Data.xlsx")
